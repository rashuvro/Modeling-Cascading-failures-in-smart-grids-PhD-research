# %%
import pandas as pd

# %%
df = pd.read_excel('numFailedType.xlsx')
print("Column headings:")
print(df.columns)
# Out:
# Column headings:
# Index(['20 W', '60 MW', '120 MW', '200 MW', '332 MW', 'Total'], dtype='object')

# %%
df.head()
# Out:
#    20 W  60 MW  120 MW  200 MW  332 MW  Total
# 0     5      3       1       1       0     10
# 1     7      3       0       1       0     11
# 2     7      3       0       1       0     11
# 3     5      0       1       1       0      7
# 4     6      1       1       0       0      8

# %%
by_total_count = df.groupby("Total").count()
by_total_count
# Out:
#        20 W  60 MW  120 MW  200 MW  332 MW
# Total
# 3         6      6       6       6       6
# 4        29     29      29      29      29
# 5       126    126     126     126     126
# 6       294    294     294     294     294
# 7       644    644     644     644     644
# 8      1143   1143    1143    1143    1143
# 9      1673   1673    1673    1673    1673
# 10     1736   1736    1736    1736    1736
# 11      768    768     768     768     768
# 12      421    421     421     421     421
# 13      250    250     250     250     250
# 14      192    192     192     192     192
# 15      112    112     112     112     112
# 16       45     45      45      45      45
# 17       42     42      42      42      42
# 18       45     45      45      45      45
# 19       61     61      61      61      61
# 20       89     89      89      89      89
# 21       98     98      98      98      98
# 22      146    146     146     146     146
# 23      166    166     166     166     166
# ...

# %%
by_total_sum = df.groupby("Total").sum()
by_total_sum
# Out:
#         20 W  60 MW  120 MW  200 MW  332 MW
# Total
# 3         16      2       0       0       0
# 4         90     11      11       4       0
# 5        450     82      71      24       3
# 6       1223    252     204      62      23
# 7       2993    715     556     204      40
# 8       5884   1734    1087     325     114
# 9       9599   3300    1575     430     153
# 10     10666   4083    1848     586     177
# 11      5244   2075     712     341      76
# 12      3231   1183     395     194      49
# 13      2015    849     250     109      27
# 14      1548    797     237      89      17
# 15       893    549     188      44       6
# 16       420    195      72      24       9
# 17       428    180      80      17       9
# 18       487    201      92      22       8
# 19       658    319     155      16      11
# 20      1008    492     242      32       6
# 21      1130    594     293      28      13
# 22      1751    949     446      53      13
# ...

# %%
by_total_avg = df.groupby("Total").mean()
by_total_avg
#by_total_avg.mean()
#by_total_avg.plot.bar(stacked=True,figsize=(10,10))
# Out:
#             20 W      60 MW     120 MW    200 MW    332 MW
# Total
# 3       2.666667   0.333333   0.000000  0.000000  0.000000
# 4       3.103448   0.379310   0.379310  0.137931  0.000000
# 5       3.571429   0.650794   0.563492  0.190476  0.023810
# 6       4.159864   0.857143   0.693878  0.210884  0.078231
# 7       4.647516   1.110248   0.863354  0.316770  0.062112
# 8       5.147857   1.517060   0.951006  0.284339  0.099738
# 9       5.737597   1.972504   0.941423  0.257023  0.091452
# 10      6.144009   2.351959   1.064516  0.337558  0.101959
# 11      6.828125   2.701823   0.927083  0.444010  0.098958
# 12      7.674584   2.809976   0.938242  0.460808  0.116390
# 13      8.060000   3.396000   1.000000  0.436000  0.108000
# 14      8.062500   4.151042   1.234375  0.463542  0.088542
# 15      7.973214   4.901786   1.678571  0.392857  0.053571
# 16      9.333333   4.333333   1.600000  0.533333  0.200000
# 17     10.190476   4.285714   1.904762  0.404762  0.214286
# ...

# %%
by_total_avg_new = by_total_avg.iloc[2:49]
by_total_avg_new
# Out:
#             20 W      60 MW    120 MW    200 MW    332 MW
# Total
# 5       3.571429   0.650794  0.563492  0.190476  0.023810
# 6       4.159864   0.857143  0.693878  0.210884  0.078231
# 7       4.647516   1.110248  0.863354  0.316770  0.062112
# 8       5.147857   1.517060  0.951006  0.284339  0.099738
# 9       5.737597   1.972504  0.941423  0.257023  0.091452
# 10      6.144009   2.351959  1.064516  0.337558  0.101959
# 11      6.828125   2.701823  0.927083  0.444010  0.098958
# 12      7.674584   2.809976  0.938242  0.460808  0.116390
# 13      8.060000   3.396000  1.000000  0.436000  0.108000
# 14      8.062500   4.151042  1.234375  0.463542  0.088542
# 15      7.973214   4.901786  1.678571  0.392857  0.053571
# 16      9.333333   4.333333  1.600000  0.533333  0.200000
# 17     10.190476   4.285714  1.904762  0.404762  0.214286
# 18     10.822222   4.466667  2.044444  0.488889  0.177778
# 19     10.786885   5.229508  2.540984  0.262295  0.180328
# ...

# %%
import matplotlib.ticker as ticker
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
axes = by_total_sum.plot.bar(stacked=True,figsize=(12,10))
axes.tick_params(axis='x', which='major', labelsize=14) # We change the fontsize of minor ticks label
axes.tick_params(axis='y', which='major', labelsize=25) # We change the fontsize of minor ticks label
## Major ticks every 5 for x axis
#major_ticks = np.arange(0, 55, 5)
#minor_ticks = np.arange(0, 55, 1)
#axes.set_xticks([0, 5, 10, 15 , 20, 25, 30, 35, 40, 45, 50, 55])
#axes.set_xticks(minor_ticks, minor=True)
axes.set_xlabel('Number of failed lines when cascade stops',fontsize=30)
axes.legend(prop={'size': 30})
fig = axes.get_figure()
fig.savefig('histNumFailedType.eps')

# %%
major_ticks
# Out:
# array([ 1,  6, 11, 16, 21, 26, 31, 36, 41, 46, 51])

# %%
by_total.plot.bar()

# %%
by_total.plot.hist(stacked=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(by_total)
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-a3573f5f5175> in <module>()
# ----> 1 plt.bar(by_total)
#       2 plt.xlabel('X Axis Title Here')
#       3 plt.ylabel('Y Axis Title Here')
#       4 plt.title('String Title Here')
#       5 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(*args, **kwargs)
#    2625                       mplDeprecation)
#    2626     try:
# -> 2627         ret = ax.bar(*args, **kwargs)
#    2628     finally:
#    2629         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
# ...
